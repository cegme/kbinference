# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import itertools
from operator import itemgetter, attrgetter, methodcaller

# %% [markdown]
# # DBMS Node list Experiment

# %%
results = """hops,size,time,src,dst              
3,0,1.40,"marijuana","Fox News"
3,0,1.33,"marijuana","Fox News"
3,0,1.31,"marijuana","Fox News"
4,1947444967,233.20,"marijuana","Fox News"
4,1947444967,210.37,"marijuana","Fox News"
4,1947444967,205.93,"marijuana","Fox News"
5,74963,6.07,"marijuana","Fox News"
5,74963,4.14,"marijuana","Fox News"
5,74963,4.12,"marijuana","Fox News"
3,15,1.16,"Abortion","Hillary" 
3,15,1.12,"Abortion","Hillary"
3,15,1.12,"Abortion","Hillary"
4,149123581763,15907.16,"Abortion","Hillary"
4,149123581763,15733.96,"Abortion","Hillary"
4,149123581763,15538.13,"Abortion","Hillary"
5,6009426,12.21,"Abortion","Hillary"
5,6009426,10.55,"Abortion","Hillary"
5,6009426,10.77,"Abortion","Hillary"
3,0,1.15,"Brutality","Biden"
3,0,1.11,"Brutality","Biden"
3,0,1.11,"Brutality","Biden"
4,11523343,3.87,"Brutality","Biden"
4,11523343,3.75,"Brutality","Biden"
4,11523343,3.75,"Brutality","Biden"
5,5979,4.26,"Brutality","Biden"
5,5979,4.03,"Brutality","Biden"
5,5979,4.01,"Brutality","Biden"
"""

x = [2,3,4]

y = [1662/1000,19348/1000,270222/1000]
p1, = plt.plot(x,y,label="Reddit->Fox News",linewidth=5.0)


plt.show()

# %% [markdown]
# # Titan Experiment

# %% [markdown]
# # Titan Node list results

# %%
x = [2,3,4]

y = [1662,19348,270222]
p1, = plt.plot(x,y,label="Reddit->Fox News",linewidth=3.0)

y = [494,550,21430]
p2, = plt.plot(x,y, label="Brutality->Biden",linewidth=3.0)

y = [1037,12822,1343166]
p3, = plt.plot(x,y,label="Marijuana->Fox News",linewidth=3.0)

y = [34,13819,975784]
p4, = plt.plot(x,y,label="Marijuana->CNN",linewidth=3.0)

plt.legend(handles=[p1,p2,p3,p4], loc=2)
plt.ylabel("Time log((ms))")
plt.xlabel("Hops")
plt.grid(axis = 'y', color ='white', linestyle='-')
plt.yscale('log')

# %% [markdown]
# #Postgresql 1 Node List

# %%
x = [2,3,4]

y = [1214.813,9315.348,5183.46]
p1, = plt.plot(x,y,label="Reddit->Fox News",linewidth=3.0)

y = [1280.593, 4932.598, 13872.730]
p2, = plt.plot(x,y, label="Brutality->Biden",linewidth=3.0)

y = [5252.179,141597.583,64136.636]
p3, = plt.plot(x,y,label="Marijuana->Fox News",linewidth=3.0)


y = [1092.694,3654.444,7640.435]
p4, = plt.plot(x,y,label="Marijuana->CNN",linewidth=3.0)

plt.legend(handles=[p1,p2,p3,p4], loc=2)
plt.ylabel("Time log((ms)")
plt.xlabel("Hops")
plt.grid(axis = 'y', color ='white', linestyle='-')
plt.yscale('log')

# %% [markdown]
# # Postgresql 2 Node List

# %%
x = [2,3,4]

y = [1214.813,9315.348,11531.648]
p1, = plt.plot(x,y,label="Reddit->Fox News",linewidth=3.0)

y = [1280.593, 4932.598, 13872.730]
p2, = plt.plot(x,y, label="Brutality->Biden",linewidth=3.0)

y = [5252.179,141597.583,245465.62]
p3, = plt.plot(x,y,label="Marijuana->Fox News",linewidth=3.0)


y = [1092.694,3654.444,7640.435]
p4, = plt.plot(x,y,label="Marijuana->CNN",linewidth=3.0)

plt.legend(handles=[p1,p2,p3,p4], loc=2)
plt.ylabel("Time log((ms)")
plt.xlabel("Hops")
plt.grid(axis = 'y', color ='white', linestyle='-')
plt.yscale('log')

# %%
x = [2,3,4]

y = [(1214.813+1280.593+5252.179+1092.694)/4,(9315.348+4932.598+141597.583+3654.444)/4,(11531.648+13872.730+245465.62+7640.435)/4]
p1, = plt.plot(x,y,label="PostgreSQL",linewidth=3.0)


y = [(1662+494+1037+34)/4,(19348+550+12822+13819)/4,(270222+21430+1343116+975784)/4]
p2, = plt.plot(x,y,label="Titan DB",linewidth=3.0)


plt.legend(handles=[p1,p2], loc=2)
plt.ylabel("Time log((ms)")
plt.xlabel("Hops")
plt.grid(axis = 'y', color ='white', linestyle='-')
plt.yscale('log')
